# %%
import os
import openai 
from dotenv import load_dotenv

# %%
pip show openai
# Out:
# Name: openai
# Version: 0.28.0
# Summary: Python client library for the OpenAI API
# Home-page: https://github.com/openai/openai-python
# Author: OpenAI
# Author-email: support@openai.com
# License:
# Location: d:\programfiles\miniconda3\envs\openaidemo\lib\site-packages
# Requires: aiohttp, requests, tqdm
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
load_dotenv()
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

# %%
openai.api_key = OPENAI_API_KEY

# %%
pip install --upgrade pandas
# Out:
# Requirement already satisfied: pandas in d:\programfiles\miniconda3\envs\openaidemo\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.22.4 in d:\programfiles\miniconda3\envs\openaidemo\lib\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\programfiles\miniconda3\envs\openaidemo\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\programfiles\miniconda3\envs\openaidemo\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\programfiles\miniconda3\envs\openaidemo\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in d:\programfiles\miniconda3\envs\openaidemo\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
pd.DataFrame(openai.Model.list()['data'])
# Out:
#                              id object     created         owned_by
# 0                      dall-e-2  model  1698798177           system
# 1        text-embedding-ada-002  model  1671217299  openai-internal
# 2        text-embedding-3-large  model  1705953180           system
# 3                   babbage-002  model  1692634615           system
# 4                       o1-mini  model  1725649008           system
# 5                   davinci-002  model  1692634301           system
# 6            o1-mini-2024-09-12  model  1725648979           system
# 7                     whisper-1  model  1677532384  openai-internal
# 8                      dall-e-3  model  1698785189           system
# 9                    o1-preview  model  1725648897           system
# 10            gpt-3.5-turbo-16k  model  1683758102  openai-internal
# 11        o1-preview-2024-09-12  model  1725648865           system
# 12                tts-1-hd-1106  model  1699053533           system
# 13                gpt-3.5-turbo  model  1677610602           openai
# 14           gpt-3.5-turbo-0125  model  1706048358           system
# 15       gpt-4o-mini-2024-07-18  model  1721172717           system
# 16                  gpt-4o-mini  model  1721172741           system
# 17       text-embedding-3-small  model  1705948997           system
# 18                     tts-1-hd  model  1699046015           system
# 19           gpt-3.5-turbo-1106  model  1698959748           system
# 20       gpt-3.5-turbo-instruct  model  1692901427           system
# 21                        tts-1  model  1681940951  openai-internal
# 22                   tts-1-1106  model  1699053241           system
# 23  gpt-3.5-turbo-instruct-0914  model  1694122472           system

# %%
prompt  = "Hello, How are you?"

response = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages = [
        {"role":"system", "content":"You are a helpful assistant."},
        {"role":"user","content":prompt}
    ]
)
print(response['choices'])
# Out:
# {
#   "id": "chatcmpl-AaLefYIipsHTDo3lKlZ32FEcnBdzZ",
#   "object": "chat.completion",
#   "created": 1733226413,
#   "model": "gpt-3.5-turbo-0125",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "Hello! I'm here and ready to assist you. How can I help you today?",
#         "refusal": null
#       },
#       "logprobs": null,
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 23,
#     "completion_tokens": 18,
#     "total_tokens": 41,
#     "prompt_tokens_details": {
#       "cached_tokens": 0,
#       "audio_tokens": 0
#     },
#     "completion_tokens_details": {
#       "reasoning_tokens": 0,
#       "audio_tokens": 0,
#       "accepted_prediction_tokens": 0,
#       "rejected_prediction_tokens": 0
#     }
#   },
#   "system_fingerprint": null
# }

# %%
print(response['choices'])
print(response['choices'][0]['message']['role'])
# Out:
# [<OpenAIObject at 0x2a2a8c98270> JSON: {
#   "index": 0,
#   "message": {
#     "role": "assistant",
#     "content": "Hello! I'm here and ready to assist you. How can I help you today?",
#     "refusal": null
#   },
#   "logprobs": null,
#   "finish_reason": "stop"
# }]
# assistant

# %%
prompt1 = "Hello How are you?"
prompt2 = "I am 35 years old & I am a Consultant"
prompt3 = "Compare triumph speed 400 vs super meteor 650"

response = openai.ChatCompletion.create(
    model = "gpt-3.5-turbo",
    messages=[
        {"role":"system","content":"You are a helpful assistant"},
        {"role":"user","content": prompt1},
        {"role":"user","content": prompt2},
        {"role":"user","content": prompt3}
    ],
    # temperature = 0.6
    n = 2
)

# %%
print(response['choices'][0]['message']['content'])
# Out:
# Both the Triumph Speed Twin 1200 and the Royal Enfield Interceptor 650 offer unique riding experiences for different types of riders. Here are some key differences between the two:
#
# 1. Engine Size: The Triumph Speed Twin 1200 is powered by a larger 1200cc engine compared to the Royal Enfield Interceptor 650's 650cc engine. This means the Triumph will likely offer more power and torque, resulting in quicker acceleration and higher top speeds.
#
# 2. Performance: The Triumph Speed Twin 1200 is a more performance-oriented bike, designed for riders looking for more speed and agility. On the other hand, the Royal Enfield Interceptor 650 is more of a classic cruiser, offering a more relaxed and comfortable riding experience.
#
# 3. Price: The Triumph Speed Twin 1200 is generally more expensive than the Royal Enfield Interceptor 650 due to its larger engine size and higher performance capabilities.
#
# Ultimately, the choice between the two bikes will depend on your riding preferences and budget. If you're looking for a more powerful and dynamic ride, the Triumph Speed Twin 1200 may be the better option. If you prefer a more laid-back cruising experience with a classic look, the Royal Enfield Interceptor 650 could be the bike for you.

# %% [markdown]
# Completion API

# %%
prompt  = "what is python"

response = openai.Completion.create(
    model = "babbage-002",
    prompt = prompt

)
print(response)
# Out:
# {
#   "id": "cmpl-AaM6i01IYi2aQrnM0iWuSFnfQzVKz",
#   "object": "text_completion",
#   "created": 1733228152,
#   "model": "babbage-002",
#   "choices": [
#     {
#       "text": " programming wiki\u201d. However, by understanding a simple example, the student can easily know",
#       "index": 0,
#       "logprobs": null,
#       "finish_reason": "length"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 3,
#     "completion_tokens": 16,
#     "total_tokens": 19
#   }
# }

# %% [markdown]
# Function Calling in OPENAI
